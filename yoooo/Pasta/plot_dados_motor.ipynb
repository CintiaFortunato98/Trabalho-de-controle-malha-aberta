# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dados = pd.read_csv('C:/Users/CaioSergio/Desktop/yoooo/dados_1400rpm.csv')
# dados = pd.read_csv('dados_1000RPM.csv')


tempo = dados['tempo']
rpm = dados['RPM']

plt.figure(figsize=(10, 6))
plt.plot(tempo, rpm, linestyle='-', color='b', label='RPM')
plt.title('Variação de RPM ao longo do Tempo')
plt.xlabel('Tempo (s)')
plt.ylabel('RPM')
plt.grid(True)
plt.legend()
plt.tight_layout()




plt.show()

# %%
fig = px.line(dados, x='tempo', y='RPM', title='Variação de RPM ao longo do Tempo')
fig.update_xaxes(title='Tempo (s)')
fig.update_yaxes(title='RPM')
fig.show()

# %%
window_size = 5
dados['dados_filtrados'] = dados['RPM'].rolling(window=window_size, min_periods=1).mean()


plt.figure(figsize=(10, 6))
plt.plot(dados['tempo'], dados['RPM'], label='Dados Originais')
plt.plot(dados['tempo'], dados['dados_filtrados'], label='Dados Filtrados (Média Móvel)')
plt.xlabel('tempo')
plt.ylabel('RPM')
plt.title('Dados Originais vs Dados Filtrados')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

fig = px.line(dados, x='tempo', y='dados_filtrados', title='Variação de RPM Filtrado ao longo do Tempo')
# fig.add_scatter(x=dados['tempo'], y=dados['dados_filtrados'], mode='lines', name='RPM Filtrado')
fig.update_xaxes(title='tempo')
fig.update_yaxes(title='RPM')
fig.show()

# %%
dados_simulink = pd.read_csv("dados_simulink.csv")
print(dados_simulink.columns)
plt.figure(figsize=(10, 6))
plt.plot(dados_simulink['tempo'], dados_simulink['degrau'], label='Degrau Unitário')
plt.plot(dados_simulink['tempo'], dados_simulink['ft_discreta_senoide'], label='Resposta com Controle Discreto com Senoide')
plt.plot(dados_simulink['tempo'], dados_simulink['ft_discreta'], label='Resposta com Controle Discreto')
plt.xlabel('Tempo (s)')
plt.ylabel('RPM')
plt.title('Simulação do Simulink para o Controlador Discretizado')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


fig = px.line(dados_simulink, x='tempo', y='degrau', title='Simulação do Simulink para o Controlador Discretizado')


fig.add_scatter(x=dados_simulink['tempo'], y=dados_simulink['ft_discreta_senoide'], mode='lines', name='ft_discreta_senoide')
fig.add_scatter(x=dados_simulink['tempo'], y=dados_simulink['ft_discreta'], mode='lines', name='ft_discreta')


fig.update_xaxes(title='Tempo (s)')
fig.update_yaxes(title='Amplitude')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 dados_simulink = pd.read_csv("dados_simulink.csv")
#       2 print(dados_simulink.columns)
#       3 plt.figure(figsize=(10, 6))
#
# ...

# %%
# Leitura do arquivo combinado
dados = pd.read_csv('C:/Users/CaioSergio/Desktop/yoooo/arquivo_combinado_CERTO.csv')

tempo = dados['tempo']
rpm = dados['RPM']
pwm = dados['PWM']

fig, ax1 = plt.subplots(figsize=(10, 6))

# Gráfico de RPM
ax1.plot(tempo, rpm, 'b-', label='RPM')
ax1.set_xlabel('Tempo (s)')
ax1.set_ylabel('RPM', color='b')
ax1.tick_params('y', colors='b')
ax1.set_title('Variação de RPM e PWM ao longo do Tempo')
ax1.grid(True)

# Criando um segundo eixo y compartilhando o mesmo eixo x
ax2 = ax1.twinx()
ax2.plot(tempo, pwm, 'r-', label='PWM')
ax2.set_ylabel('PWM', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()

# Adicionando legendas
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()

# %%
# Leitura do arquivo combinado
dados = pd.read_csv('arquivo_combinado_sat.csv')

tempo = dados['Tempo (s)']
rpm = dados['RPM']
pwm = dados['PWM']

fig, ax1 = plt.subplots(figsize=(10, 6))

# Gráfico de RPM
ax1.plot(tempo, rpm, 'b-', label='RPM')
ax1.set_xlabel('Tempo (s)')
ax1.set_ylabel('RPM', color='b')
ax1.tick_params('y', colors='b')
ax1.set_title('Variação de RPM e PWM ao longo do Tempo')
ax1.grid(True)

# Criando um segundo eixo y compartilhando o mesmo eixo x
ax2 = ax1.twinx()
ax2.plot(tempo, pwm, 'r-', label='PWM')
ax2.set_ylabel('PWM', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()

# Adicionando legendas
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
